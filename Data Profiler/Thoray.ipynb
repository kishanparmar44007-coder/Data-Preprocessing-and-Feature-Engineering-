# %% [markdown]
# <style>
# body {
#     background: linear-gradient(135deg, #1f1c2c, #928dab);
#     color: white;
#     font-family: 'Segoe UI', sans-serif;
# }
# .glass {
#     background: rgba(255, 255, 255, 0.08);
#     backdrop-filter: blur(14px);
#     -webkit-backdrop-filter: blur(14px);
#     border-radius: 20px;
#     padding: 25px;
#     margin: 25px 0;
#     border: 1px solid rgba(255,255,255,0.2);
#     box-shadow: 0 8px 32px rgba(0,0,0,0.35);
# }
# </style>
#
# <!-- ================= DATA ANALYSIS ================= -->
# <div class="glass">
# <h1 style="text-align:center; color:#ECF0F1;">📊 Data Analysis</h1>
#
# <h3 style="color:#5DADE2;">📌 Definition</h3>
# <p style="color:#D6EAF8;">
# Data Analysis is the process of inspecting, cleaning, transforming, and organizing raw data to extract useful information, patterns, and insights.
# It helps in making informed decisions based on data.
# </p>
#
# <h3 style="color:#58D68D;">📊 Example</h3>
# <p style="color:#E8F8F5;">
# A company has customer purchase data. By analyzing the data, we can find which products are selling more and which are selling less.
# </p>
#
# <h3 style="color:#F5B041;">🎯 Purpose</h3>
# <p style="color:#FEF5E7;">
# - To make better business decisions <br>
# - To discover hidden patterns and trends <br>
# - To increase business growth <br>
# - To understand customer behavior
# </p>
# </div>
#
# <!-- ================= PROJECT PLANNING ================= -->
# <div class="glass">
# <h1 style="text-align:center; color:#ECF0F1;">📈 Data Science Project Planning</h1>
#
# <h3 style="color:#5DADE2;">📌 Definition</h3>
# <p style="color:#D6EAF8;">
# Data Science Project Planning is a structured process that defines all steps from problem understanding to deployment of the model.
# </p>
#
# <h3 style="color:#58D68D;">📊 Example</h3>
# <p style="color:#E8F8F5;">
# 1. Define problem <br>
# 2. Collect data <br>
# 3. Clean data <br>
# 4. Build model <br>
# 5. Evaluate model <br>
# 6. Deploy model
# </p>
#
# <h3 style="color:#F5B041;">🎯 Purpose</h3>
# <p style="color:#FEF5E7;">
# - To maintain proper workflow <br>
# - To save time and resources <br>
# - To get accurate results <br>
# - To make the project systematic
# </p>
# </div>
#
# <!-- ================= ML PROBLEM ================= -->
# <div class="glass">
# <h1 style="text-align:center; color:#ECF0F1;">🤖 Machine Learning Problem</h1>
#
# <h3 style="color:#5DADE2;">📌 Definition</h3>
# <p style="color:#D6EAF8;">
# A Machine Learning Problem Statement clearly defines what the model will predict.
# Here, the goal is to predict whether a customer will churn (leave the service) or not.
# </p>
#
# <h3 style="color:#58D68D;">📊 Example</h3>
# <p style="color:#E8F8F5;">
# Input: Customer purchase history <br>
# Output: Churn (Yes / No)
# </p>
#
# <h3 style="color:#F5B041;">🎯 Purpose</h3>
# <p style="color:#FEF5E7;">
# - To get clarity about the problem <br>
# - To choose the right machine learning model <br>
# - To achieve business goals
# </p>
# </div>
#
# <!-- ================= TENSORS ================= -->
# <div class="glass">
# <h1 style="text-align:center; color:#ECF0F1;">🧮 Tensors</h1>
#
# <h3 style="color:#5DADE2;">📌 Definition</h3>
# <p style="color:#D6EAF8;">
# A Tensor is a multi-dimensional array used to store numerical data.
# Scalars, vectors, and matrices are all types of tensors.
# </p>
#
# <h3 style="color:#58D68D;">📊 Example</h3>
#
# ```python
# import numpy as np
# scalar = np.array(5)
# vector = np.array([1,2,3])
# matrix = np.array([[1,2],[3,4]])

# %% [markdown]
# <h3 style="color:#F5B041;">🎯 Purpose</h3> <p style="color:#FEF5E7;"> - Used in Deep Learning and Neural Networks <br> - Efficient data storage <br> - Faster mathematical computations </p> </div> <!-- ================= DATA CLEANING ================= --> <div class="glass"> <h1 style="text-align:center; color:#ECF0F1;">🧹 Data Cleaning</h1> <h3 style="color:#5DADE2;">📌 Definition</h3> <p style="color:#D6EAF8;"> Data Cleaning is the process of fixing or removing incorrect, missing, or duplicate data from a dataset. </p> <h3 style="color:#58D68D;">📊 Example</h3> <p style="color:#E8F8F5;"> - Removing null values <br> - Deleting duplicate rows <br> - Correcting incorrect values </p> <h3 style="color:#F5B041;">🎯 Purpose</h3> <p style="color:#FEF5E7;"> - To improve data quality <br> - To ensure accurate analysis <br> - To improve model performance </p> </div> <!-- ================= EDA ================= --> <div class="glass"> <h1 style="text-align:center; color:#ECF0F1;">📊 Exploratory Data Analysis</h1> <h3 style="color:#5DADE2;">📌 Definition</h3> <p style="color:#D6EAF8;"> EDA is the process of analyzing and visualizing data to understand patterns, relationships, and distributions. </p> <h3 style="color:#58D68D;">📊 Example</h3> <p style="color:#E8F8F5;"> - Histogram <br> - Boxplot <br> - Correlation heatmap </p> <h3 style="color:#F5B041;">🎯 Purpose</h3> <p style="color:#FEF5E7;"> - To understand the dataset <br> - To find trends and patterns <br> - To detect outliers </p> </div> <!-- ================= CSV ================= --> <div class="glass"> <h1 style="text-align:center; color:#ECF0F1;">📂 CSV Loading</h1> <h3 style="color:#5DADE2;">📌 Definition</h3> <p style="color:#D6EAF8;"> Loading CSV files into a Pandas DataFrame for analysis. </p> <h3 style="color:#58D68D;">📊 Example</h3>

# %%
import pandas as pd
df = pd.read_csv("data.csv")
print(df.head())

# %% [markdown]
# <h3 style="color:#F5B041;">🎯 Purpose</h3> <p style="color:#FEF5E7;"> - To access structured data easily <br> - To simplify data analysis </p> </div> <!-- ================= JSON ================= --> <div class="glass"> <h1 style="text-align:center; color:#ECF0F1;">📄 JSON Parsing</h1> <h3 style="color:#5DADE2;">📌 Definition</h3> <p style="color:#D6EAF8;"> JSON Parsing is the process of extracting data from a JSON file format. </p> <h3 style="color:#58D68D;">📊 Example</h3>

# %%
import json
with open("data.json") as f:
    data = json.load(f)

# %% [markdown]
# <h3 style="color:#F5B041;">🎯 Purpose</h3> <p style="color:#FEF5E7;"> - To handle API data <br> - To read nested data structures </p> </div> <!-- ================= SQL ================= --> <div class="glass"> <h1 style="text-align:center; color:#ECF0F1;">🗄️ SQL Data Fetching</h1> <h3 style="color:#5DADE2;">📌 Definition</h3> <p style="color:#D6EAF8;"> Fetching data from a database using SQL queries. </p> <h3 style="color:#58D68D;">📊 Example</h3>

# %%
SELECT * FROM customers;

import sqlite3
import pandas as pd
conn = sqlite3.connect("db.db")
df = pd.read_sql_query("SELECT * FROM customers", conn)

# %% [markdown]
# <h3 style="color:#F5B041;">🎯 Purpose</h3> <p style="color:#FEF5E7;"> - To access large datasets <br> - To perform real-time data analysis </p> </div> <!-- ================= API ================= --> <div class="glass"> <h1 style="text-align:center; color:#ECF0F1;">🌐 API Data Fetching</h1> <h3 style="color:#5DADE2;">📌 Definition</h3> <p style="color:#D6EAF8;"> Fetching data from an online server using an API. </p> <h3 style="color:#58D68D;">📊 Example</h3>

# %%
import requests
response = requests.get("https://api.example.com/data")
data = response.json()

# %% [markdown]
# <h3 style="color:#F5B041;">🎯 Purpose</h3> <p style="color:#FEF5E7;"> - To get live data <br> - To automate data collection <br> - To work with real-world applications </p> </div>
